# %%
# !pip install panda

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df=pd.DataFrame([{'name':"Garima",'age':50}])

# %%
df
# Out:
#      name  age
# 0  Garima   50

# %%
df.head(1)
# Out:
#      name  age
# 0  Garima   50

# %%
df.tail(2)
# Out:
#      name  age
# 0  Garima   50

# %%
houseData=pd.read_csv('House_Data.csv')

# %%
type(houseData)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('House_Data.csv')
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
houseData.head(3)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00

# %%
houseData.shape
# Out:
# (13320, 9)

# %%
import mysql.connector as sql
conn=sql.connect(host='localhost',password='Gunik@2109',user='root',database='employee')
mydata=pd.read_sql('select * from EMPdetails;',con=conn)
mydata.head()
# Out:
# /var/folders/_2/6mthtwr109b0mkgfdfwmc8400000gn/T/ipykernel_32651/3364657860.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   mydata=pd.read_sql('select * from EMPdetails;',con=conn)
#     EName  Eid  Erating
# 0  Chhavi    1       10

# %%
houseData=pd.read_csv('House_Data.csv')

# %%
print(f"Shape of Data-Set- {houseData.shape}")
print(f"Attributes - {houseData.columns}")
# Out:
# Shape of Data-Set- (13320, 9)
# Attributes - Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
houseData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7821 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
houseData.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
houseData.isnull().count()
# Out:
# area_type       13320
# availability    13320
# location        13320
# size            13320
# society         13320
# total_sqft      13320
# bath            13320
# balcony         13320
# price           13320
# dtype: int64

# %%
houseData.columns #to get name of all columns
#.loc to get data of a particluar column
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
total_sqrft=houseData.loc[:,"total_sqft"]
type(total_sqrft)
# Out:
# pandas.core.series.Series

# %%
data=[10,20,30]
series=pd.Series(data,index=['a','b','c'])
print(series)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data={"Name":["Alice","Bob","Charlie"],
      "Age":[19,20,20],
      "City":["New York","Los Angeles","Chicago"]}
data_Frame=pd.DataFrame(data)
print(data_Frame)
# Out:
#       Name  Age         City
# 0    Alice   19     New York
# 1      Bob   20  Los Angeles
# 2  Charlie   20      Chicago

# %%
houseData
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
houseData.head() #first 5 rows
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
houseData.tail() #last 5 rows
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
houseData.shape #(rows,columns)
# Out:
# (13320, 9)

# %%
houseData.columns # return column names of DataFrame
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
houseData.dtypes #to get data-type of each column
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
houseData
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
houseData.describe() #provides summary statistics for numerical columns of a data frame
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
houseData.isnull().sum() #count missing value cells in each column
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5499
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
houseData['bath']#Select a particular column
# Out:
# 0        2.0
# 1        5.0
# 2        2.0
# 3        3.0
# 4        2.0
#         ...
# 13315    4.0
# 13316    5.0
# 13317    2.0
# 13318    4.0
# 13319    1.0
# Name: bath, Length: 13320, dtype: float64

# %%
houseData[['bath','balcony']] #to access multiple columns
# Out:
#        bath  balcony
# 0       2.0      1.0
# 1       5.0      3.0
# 2       2.0      3.0
# 3       3.0      1.0
# 4       2.0      1.0
# ...     ...      ...
# 13315   4.0      0.0
# 13316   5.0      NaN
# 13317   2.0      1.0
# 13318   4.0      1.0
# 13319   1.0      1.0
#
# [13320 rows x 2 columns]

# %%
houseData.iloc[2] #gives data of row with index 2
# Out:
# area_type       Built-up  Area
# availability     Ready To Move
# location           Uttarahalli
# size                     3 BHK
# society                    NaN
# total_sqft                1440
# bath                       2.0
# balcony                    3.0
# price                     62.0
# Name: 2, dtype: object
