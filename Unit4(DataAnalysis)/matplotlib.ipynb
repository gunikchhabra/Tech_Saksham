# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np

# %%
x=np.array([10,20,30])
y=np.array([100,400,900])
plt.plot(x,y)
plt.show()

# %%
gender=np.array([65,50])
label=["Male","Female"]
plt.pie(gender,labels=label,autopct='%1.1f%%')
plt.show()
labell=np.array(["Male","Female"])
plt.bar(label,gender)
plt.show()
plt.scatter(label,gender)
plt.show()
xx=np.array([1,2,3,4,5,6,78,9])
yy=np.array([2,4,6,7,8,9,10,11])
plt.scatter(xx,yy)
plt.show()

# %%
# !pip install seaborn
